# %%
import seaborn as sns

# %% [markdown]
# ### Question 1.

# %% [markdown]
# 1. **Scatter Plot** get the information that how data is behacing like data is grouped or not & is x & y proposanal. IN scatter graph we can find out.
# 2. **Histogram** to get frequency of any categorical or numerical data.
# 3. **Heatmap** to show corelation b/w two data set by using some colors in graph.
# 4. **pairplot** to show all numerical in graph at same figure.

# %% [markdown]
# ### Question 2.

# %%
fmri = sns.load_dataset("fmri")

sns.lineplot(x=fmri["timepoint"], y=fmri["signal"])
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
