# %%
# https://drive.google.com/file/d/1e7COtyubXMeNquT8mJQYL8DuR_vNszje/view?usp=share_link
import numpy as np
from statistics import mode
import pandas as pd
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %% [markdown]
# ### Question 1.

# %% [markdown]
# 1. Mean
# 2. Median
# 3. Mode

# %% [markdown]
# ### Question 2.

# %% [markdown]
# 1. **Mean**- It is a avverage og fiven data.

# %%
iris.sepal_length.mean()
# Out:
# 5.843333333333334

# %% [markdown]
# 2. Median

# %%
iris.sepal_length.median()
# Out:
# 5.8

# %% [markdown]
# 3. Mode

# %%
mode(iris.sepal_length)
# Out:
# 5.0

# %% [markdown]
# ### Question 3.

# %%
np3 = np.array([178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5])
print("1. Mean - ", np3.mean())
print("2. Median - ", np.median(np3))
print("3. Mode - ", mode(np3))
# Out:
# 1. Mean -  177.01875
# 2. Median -  177.0
# 3. Mode -  178.0

# %% [markdown]
# ### Question 4.

# %%
print(np.std(np3))
# Out:
# 1.7885814036548633

# %% [markdown]
# ### Question 5.

# %% [markdown]
# 1. **Range** - Range just a way to provide how much data is spreaded. Here need to substract minumum from maximum.

# %%
max = np3.max()
min = np3.min()

print("Range => ", max - min)
# Out:
# Range =>  7.5

# %% [markdown]
# 2. **variance** - Its a sum of sequared difference b/w number & mean.

# %%
np3.var()
# Out:
# 3.199023437500001

# %% [markdown]
# 3. **standard deviation** - That is just sequare root of varience. It's a measure of extent to which data varies from mean.

# %%
np3.std()
# Out:
# 1.7885814036548633

# %% [markdown]
# ### Question 6.

# %% [markdown]
# Venn digram is a way to show logical relationship between two set.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 7.

# %%
a = np.array([2,3,4,5,6,7])
b = np.array([0,2,6,8,10])

print("Union => ", np.union1d(a, b))
print("intersect => ", np.intersect1d(a, b))
# Out:
# Union =>  [ 0  2  3  4  5  6  7  8 10]
# intersect =>  [2 6]

# %% [markdown]
# ### Question 8.

# %% [markdown]
# Skewness is a measure of distortion in data disribution. In bell curve we can say zero skweness.
#
# But if data is distorted from ledt side that is called left skewness abd same in if it is right side distortion that will be right skewness.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 9.

# %% [markdown]
# IN that case mean will greater than median. Because mean is sensitive to outlier.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 10.

# %% [markdown]
# Both are use to show relationship b/w two variables.
#
# Covariance is measure tha how one variable changes by other variable.
#
# **For population** -
#
# ![image.png](attachment:image.png)
#
# **For Sample** -
#
# ![image.png](attachment:image-2.png)
#
# And Correlation show how strongly both are related to & that measure in -1 to +1

# %% [markdown]
# ### Question 11.

# %% [markdown]
# The sample mean is the average value of a dataset.

# %%
np11 = np.array([72, 84, 65, 91, 78, 80, 73, 68, 85, 77])
np11.mean()
# Out:
# 77.3

# %% [markdown]
# ### Question 12.

# %% [markdown]
# ### Question 7.
